# %% [markdown]
# <a href="https://colab.research.google.com/github/marianarada/ciencia-datos-clase/blob/main/Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1

print ("hola mundo")
# Out:
# hola mundo
